# %% [markdown]
# # CSC115 Lab 00 - Test Your Anaconda/VSCode Installation
#
# Once you open this file in VSCode
# 1. In the toolbar click the word "Manage" in the Restricted Mode prompt<br>
# 	<img src="https://i.postimg.cc/rppvg2WN/vscode-restricted-mode-toolbar.png" alt="Manage" width=500><br>
# 2. Click the "Trust" button
# 3. Under "Trusted Folders & Workspaces" click Add Folder.  Find your **Documents** folder and click "Trust Folder".  Also add your **Downloads** folder.<br>
# 	<img src="https://i.postimg.cc/Dz778SMz/vscode-trusted-folders.png" alt="trusted folders" width=400><br>
# 4. Close and reopen this file in VSCode
#
# 4. Follow the rest of the instructions in the <u>**Installing Anaconda and VSCode**</u> and the <u>**Configure VSCode**</u> Documents in D2L
#
# 5. **Show** the output of the code to your Instructor to get credit for this lab
#     * Don't forget to **introduce** yourself
#
# <br>
#
# <font size=2>** Don't worry if you don't understand the code just yet...you will in a few short weeks</font>
#
# <hr>

# %%
try:
    # import libraries
    import sys
    import numpy
    import matplotlib
except Exception as e:
    print("Library not imported", e)
else:
    print("Libraries successfully imported\n")

    # Print versions
    print("Python Version: ", sys.version)
    print("NumPy Version:  ", numpy.__version__)
    print("Matplot Version:", matplotlib.__version__)
# Out:
# Libraries successfully imported
#
# Python Version:  3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# NumPy Version:   2.3.5
# Matplot Version: 3.10.6
