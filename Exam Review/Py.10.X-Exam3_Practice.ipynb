# %% [markdown]
# # CSC115
#
# # Exam #3 Practice Problems

# %% [markdown]
# <hr>

# %% [markdown]
# ## <font color="green">Let's Talk About Some Concepts</font>
# You will need to look in your notes to find the answers to these
#
#
# ### Unit 7 - NumPy
# 1.  What is NumPy?
# 2.  Who created it?
# 3.  How do you create a NumPy array, from a list or tuple?
# 4.  How do you create a NumPy array of random integers?
# 5.  How do we find the shape, number of elements and number of dimensions of an array?
# 6.  NumPy math is broadcast **element-wise**.  What does this mean?
# 7.  How many dimensions does the array [3 4 6 9] have?
# 8.  How do you slice the 2nd row of a 2D array?
# 9.  How do you slice the last element of an array?  What about the second-to-last?
# 10. How do you change the shape of an array?
# 11. How are len() and np.size() different?
# 12. How do you do trig math on NumPy arrays?
# 13. Generate an array of 50 evenly spaced values from 1 - 10,000
# 14. Generate an array of values from 1-50 inclusive that are separated by 0.5
#
#
# <br><br>

# %% [markdown]
# ### Unit 8 - Matplotlib
# 1. What is Matplotlib?
# 2. Who created it?
# 3. What is the function to create a 6x6 plot figure?
# 4. How do we plot x vs y with a dotted line color of blue?
# 5. How do you show the legend on a plot?
# 6. Plot the functions $y$ = $x^3 -5$ from $x$ = -10 to $x$ = 30
# 7. How do we increase the resolution of a plotted function?
#
#
# <br><br>

# %% [markdown]
# ### Unit 9 - Artificial Intelligence
# 1. How long has AI been around?
# 2. Who made the famous test for AI?
# 3. What are some ethical issues around AI and its use?
# 4. What are some common prompting frameworks?
#
# <br><br>

# %% [markdown]
# ### Unit 10 - Advanced NumPy, Files and Exceptions
# 1. Python Files
#     1. How do we open a file for read in base Python?
#     2. What are the three functions to read files?  How are they different?
#     3. What are the two main ways to create a file?
#     4. What is the difference between write and append?
#     5. How do we write a file?
#     6. What must we always do after opening a file?
#     7. What special statement will take care of closing a file for us?
# 2. NumPy CSV Files
#     1. How to read a csv file into a NumPy array?
#     2. What argument do we change if the file is comma separated?
#     3. What about if it is a file of ints and has a header row?
# 3. Exceptions
#     1. What is the purpose of the `try` `except` block?
#     2. When do we use the `else` block?
#     3. What does the `finally` block do?
#     4. What exception is raised when the file is not found?
#     5. How do we get the general exception message?
# 4. Multi-dimensional arrays
#     1. How many dimensions does the following array have?
#         ```text
#                [[2 8]
#                 [4 7]
#                 [6 9]]
#         ```
#     2. How do we find the number of elements in a 2D NumPy array?  How about a 3D array?
#     3. How do you find the max, min, sum, mean of an array?
#     4. How do you find where the max of an array is located?

# %% [markdown]
# <hr>
#
# <br>
#
# ## Part I

# %% [markdown]
# <br>
#
# ### 1. Make a 2D array of the numbers 11 to 50 in 4 rows of 10 columns. Print it.
# * Use either `np.arange` or `np.linspace`
# * Use `.reshape` to make it 2D

# %% [markdown]
# <br>
#
# ### 2. Now change it to an array of 5 rows of 8 columns. Print it.

# %% [markdown]
# <br>
#
# ### 3. Just print:
# * The element in the second row and 5th column
# * The third row only
# * The fourth column only
# * The upper right square of 4 items

# %% [markdown]
# <br>
#
# ### 4. Print some stats
# * The number of dimensions
# * The shape
# * The size
# * The datatype

# %% [markdown]
# <br>
#
# ### 5. In one step, make a 5 by 5 array of random numbers between 10 and 15.
# * Print it.

# %% [markdown]
# <hr>
#
# <br>
#
# ## Part II

# %% [markdown]
# <br>
#
# ### 1. Use `try` to open a nonexistent file with np.loadtxt
# * Call your file "myfile.txt"
# * Catch the error

# %% [markdown]
# <br>
#
# ### 2. Run the following code to create a file called "myfile2.txt"

# %%
# generate random data here
import random

with open("myfile2.txt", "w") as myfile:
    myfile.write("x,y1,y2\n")
    myfile.write("time(s),sample1,sample2\n")
    
    for i in range(50):
        myfile.write(str(i) + "," + str(random.randint(700, 3000)) + "," + str(random.randint(800, 2700)) + "\n")

# %% [markdown]
# ### Now...Take a look at this file
# * How many header rows does it have?
# * Can you read the file data into a NumPy array ignoring these header rows?
# * What is the delimiter and datatype?

# %% [markdown]
# <br>
#
# ### 3. Plot the data from myfile2.txt
# * Put $x$ vs $y1$ and $x$ vs $y2$ on the same graph
